# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:
admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
admissions = admissions.dropna()


admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
admissions.set_index('Serial No.', inplace=True, drop=False)


admissions.head()
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        316          104                  3  3.0  3.5
# 3                    3        322          110                  3  3.5  2.5
# 4                    4        314          103                  2  2.0  3.0
# 5                    5        330          115                  5  4.5  3.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1             0.92
# 2           8.00         1             0.72
# 3           8.67         1             0.80
# 4           8.21         0             0.65
# 5           9.34         1             0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# value_counts(): devuelve una serie que contiene el recuento de valores únicos de una columna especificada
# o lista de columnas


len(admissions[["GRE Score","CGPA"]].value_counts()) == len(admissions)
# Out:
# True

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %%
admissions = admissions.groupby(['GRE Score', 'CGPA']).mean()


admissions.head()
# Out:
#                 Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# GRE Score CGPA
# 290       7.46       113.0        104.0                4.0  2.0  2.5
#           7.56       363.0        100.0                1.0  1.5  2.0
# 293       7.80       162.0         97.0                2.0  2.0  4.0
# 294       7.36        76.0         93.0                1.0  1.5  2.0
#           7.64       260.0         95.0                1.0  1.5  1.5
#
#                 Research  Chance of Admit
# GRE Score CGPA
# 290       7.46       0.0             0.45
#           7.56       0.0             0.47
# 293       7.80       1.0             0.64
# 294       7.36       0.0             0.46
#           7.64       0.0             0.49

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
admissions.reset_index(drop=False, inplace=True)


admissions.head()
# Out:
#    GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0        290  7.46       113.0        104.0                4.0  2.0  2.5
# 1        290  7.56       363.0        100.0                1.0  1.5  2.0
# 2        293  7.80       162.0         97.0                2.0  2.0  4.0
# 3        294  7.36        76.0         93.0                1.0  1.5  2.0
# 4        294  7.64       260.0         95.0                1.0  1.5  1.5
#
#    Research  Chance of Admit
# 0       0.0             0.45
# 1       0.0             0.47
# 2       1.0             0.64
# 3       0.0             0.46
# 4       0.0             0.49

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
df = admissions

# %%
condicion1 = (df["Research"] == 1)


condicion2 = (df["CGPA"] > 9)

# %%
df_final = df[condicion1 & condicion2]   # filtro

df_final.head()
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 112        310  9.04       111.0        106.0                4.0  4.5  4.5
# 164        314  9.04        70.0        108.0                4.0  4.5  4.0
# 198        317  9.11       269.0        110.0                3.0  4.0  4.5
# 207        318  9.22        65.0        109.0                3.0  3.5  4.0
# 227        320  9.20        32.0        110.0                5.0  5.0  5.0
#
#      Research  Chance of Admit
# 112       1.0             0.66
# 164       1.0             0.84
# 198       1.0             0.80
# 207       1.0             0.68
# 227       1.0             0.88

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
condicion3 = (df["SOP"] < 3.5)


condicion4 = (df["CGPA"] > 9)

# %%
df_final2 = df[condicion3 & condicion4]   # filtro


#df_final2.head()


df_final2["Chance of Admit"].mean()
# Out:
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def estandarizador(x):
    
    #x-media/std
    
    
    media = np.mean(x)
    
    std = np.std(x)
    
    
    return (x-media)/std

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# se podría hacer esto con apply? cómo?

admissions['CGPA_std'] = estandarizador(admissions['CGPA'])


admissions.head()
# Out:
#    GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0        290  7.46       113.0        104.0                4.0  2.0  2.5
# 1        290  7.56       363.0        100.0                1.0  1.5  2.0
# 2        293  7.80       162.0         97.0                2.0  2.0  4.0
# 3        294  7.36        76.0         93.0                1.0  1.5  2.0
# 4        294  7.64       260.0         95.0                1.0  1.5  1.5
#
#    Research  Chance of Admit  CGPA_std
# 0       0.0             0.45 -1.890103
# 1       0.0             0.47 -1.723881
# 2       1.0             0.64 -1.324946
# 3       0.0             0.46 -2.056326
# 4       0.0             0.49 -1.590902

# %%
admissions['GRE_std'] = estandarizador(admissions['GRE Score'])


admissions.head()
# Out:
#    GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0        290  7.46       113.0        104.0                4.0  2.0  2.5
# 1        290  7.56       363.0        100.0                1.0  1.5  2.0
# 2        293  7.80       162.0         97.0                2.0  2.0  4.0
# 3        294  7.36        76.0         93.0                1.0  1.5  2.0
# 4        294  7.64       260.0         95.0                1.0  1.5  1.5
#
#    Research  Chance of Admit  CGPA_std   GRE_std
# 0       0.0             0.45 -1.890103 -2.315684
# 1       0.0             0.47 -1.723881 -2.315684
# 2       1.0             0.64 -1.324946 -2.055810
# 3       0.0             0.46 -2.056326 -1.969186
# 4       0.0             0.49 -1.590902 -1.969186

# %%
admissions['LOR_std'] = estandarizador(admissions['LOR'])


admissions.head()
# Out:
#    GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0        290  7.46       113.0        104.0                4.0  2.0  2.5
# 1        290  7.56       363.0        100.0                1.0  1.5  2.0
# 2        293  7.80       162.0         97.0                2.0  2.0  4.0
# 3        294  7.36        76.0         93.0                1.0  1.5  2.0
# 4        294  7.64       260.0         95.0                1.0  1.5  1.5
#
#    Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0       0.0             0.45 -1.890103 -2.315684 -1.039517
# 1       0.0             0.47 -1.723881 -2.315684 -1.597696
# 2       1.0             0.64 -1.324946 -2.055810  0.635019
# 3       0.0             0.46 -2.056326 -1.969186 -1.597696
# 4       0.0             0.49 -1.590902 -1.969186 -2.155874

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:
from random import choices
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])

# %%
decision_choice
# Out:
# ['LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
# ...

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# DataFrame.lookup(self, row_labels, col_labels)


admissions['deciding_column'] = df.lookup(decision_choice, std_columns)
# Out:
# /var/folders/q3/mvdqcsqd66g2sjy7y39hmm7c0000gn/T/ipykernel_722/2072806321.py:4: FutureWarning: The 'lookup' method is deprecated and will be removed in a future version. You can use DataFrame.melt and DataFrame.loc as a substitute.
#   admissions['deciding_column'] = df.lookup(decision_choice, std_columns)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 4
#       1 # DataFrame.lookup(self, row_labels, col_labels)
# ----> 4 admissions['deciding_column'] = df.lookup(decision_choice, std_columns)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:4964, in DataFrame.lookup(self, row_labels, col_labels)
#    4962 n = len(row_labels)
#    4963 if n != len(col_labels):
# -> 4964     raise ValueError("Row labels must have same size as column labels")
#    4965 if not (self.index.is_unique and self.columns.is_unique):
#    4966     # GH#33041
# ...

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
admissions.columns = admissions.columns.str.replace('.', '').str.replace(' ', '_').str.lower()



admissions.columns
# Out:
# /var/folders/q3/mvdqcsqd66g2sjy7y39hmm7c0000gn/T/ipykernel_755/301974917.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   admissions.columns = admissions.columns.str.replace('.', '').str.replace(' ', '_').str.lower()
# Index(['gre_score', 'cgpa', 'serial_no', 'toefl_score', 'university_rating',
#        'sop', 'lor', 'research', 'chance_of_admit', 'cgpa_std', 'gre_std',
#        'lor_std'],
#       dtype='object')

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
def boosteador(student):
    
    if student['university_rating'] >= 4:
        return student['gre_score'] + 10
    
    else:
        return student['gre_score']

# %%
admissions['adjusted_gre'] = admissions.apply(boosteador, axis = 1)


admissions.head()
# Out:
#    gre_score  cgpa  serial_no  toefl_score  university_rating  sop  lor  \
# 0        290  7.46      113.0        104.0                4.0  2.0  2.5
# 1        290  7.56      363.0        100.0                1.0  1.5  2.0
# 2        293  7.80      162.0         97.0                2.0  2.0  4.0
# 3        294  7.36       76.0         93.0                1.0  1.5  2.0
# 4        294  7.64      260.0         95.0                1.0  1.5  1.5
#
#    research  chance_of_admit  cgpa_std   gre_std   lor_std  adjusted_gre
# 0       0.0             0.45 -1.890103 -2.315684 -1.039517           300
# 1       0.0             0.47 -1.723881 -2.315684 -1.597696           290
# 2       1.0             0.64 -1.324946 -2.055810  0.635019           293
# 3       0.0             0.46 -2.056326 -1.969186 -1.597696           294
# 4       0.0             0.49 -1.590902 -1.969186 -2.155874           294

# %%
admissions['adjusted_gre'] = pd.cut(admissions['adjusted_gre'], 4)


# cortada en 4 intervalos

admissions['adjusted_gre'].value_counts()
# Out:
# (305.0, 320.0]     150
# (320.0, 335.0]      90
# (335.0, 350.0]      75
# (289.94, 305.0]     70
# Name: adjusted_gre, dtype: int64
